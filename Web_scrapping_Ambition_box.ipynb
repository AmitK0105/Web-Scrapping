# %%
#!pip install pandas
#!pip install requests
#!pip install Beautifulsoup4
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
headers= {'User-Agent':'Mozilla/5.0 (Window NT 10.0; win64; x64) Applewebkit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
Web_Page = requests.get("https://www.ambitionbox.com/list-of-companies?page=1", headers= headers).text
Web_Page1 = requests.get("https://www.ambitionbox.com/salaries?page=1", headers= headers).text
Web_Page2= requests.get("https://www.linkedin.com/jobs/search/?currentJobId=3910692481&geoId=115884833&keywords=data%20analyst&location=Gurugram%2C%20Haryana%2C%20India&origin=JOB_SEARCH_PAGE_LOCATION_AUTOCOMPLETE&originalSubdomain=in&refresh=true", headers=headers).text
#requests.get("https://www.youtube.com/results?search_query=Data+Science", headers= headers).text

# %%
soup= BeautifulSoup(Web_Page, 'html.parser')
soup1= BeautifulSoup(Web_Page1, 'html.parser')
soup2=BeautifulSoup(Web_Page2, 'html.parser')

# %%
#print(soup.prettify())
#print(soup1.prettify())
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="d_jobs_guest_search" name="pageKey"/>
#   <!-- -->
#   <meta content="urlType=jserp_custom;emptyResult=false" name="linkedin:pageTag"/>
#   <meta content="en_US" name="locale"/>
#   <meta data-app-version="2.0.1742" data-browser-id="c79dfa01-afb3-4359-8823-3daf1b19c443" data-call-tree-id="AAYXsOCC6i6edIn9z9xPSw==" data-disable-jsbeacon-pagekey-suffix="false" data-enable-page-view-heartbeat-tracking="" data-member-id="0" data-multiproduct-name="jobs-guest-frontend" data-page-instance="urn:li:page:d_jobs_guest_search;GXDoqCZTTyanxE+aHoXd0Q==" data-service-name="jobs-guest-frontend" id="config"/>
#   <link href="https://in.linkedin.com/jobs/data-analyst-jobs-gurugram" rel="canonical"/>
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <link href="https://static.licdn.com/aero-v1/sc/h/al2o9zrvru7aqj8e1x2rzsrca" rel="icon"/>
#   <script>
# ...

# %%
https://www.ambitionbox.com/salaries/tcs-salaries

# %%
print(soup.find_all('h1')[0].text)
print(soup1.find_all('h1')[0].text)
print(soup2.find_all('h1')[0].text)
# Out:
# 							List of companies in India
#
#
# 		Search and Compare Salaries
#
#
# 2,000+ Data Analyst Jobs in Gurugram

# %%
print(len(soup.find_all('h2')))
print(len(soup1.find_all('h2')))
# Out:
# 24
# 5

# %%
for i in soup1.find_all('p', class_='name bold-section-header'):
    print(i.text.strip())
# Out:
# TCS
# Accenture
# Cognizant
# Infosys
# Wipro
# Capgemini
# HCLTech
# Tech Mahindra
# IBM
# Genpact

# %%
for i in soup.find_all('h2'):
    print(i.text.strip())
# Out:
# TCS
# Accenture
# Cognizant
# Wipro
# Capgemini
# HDFC Bank
# ICICI Bank
# Infosys
# HCLTech
# Tech Mahindra
# Genpact
# Axis Bank
# Teleperformance
# Concentrix Corporation
# Jio
# Amazon
# IBM
# Reliance Retail
# HDB Financial Services
# Larsen & Toubro Limited
# Companies by  Industry
# Companies by  Locations
# Companies by  Type
# Companies by  Badges

# %%
for i in soup.find_all('span', class_='companyCardWrapper__companyRatingValue'):
    print(i.text.strip())
# Out:
# 3.8
# 4.0
# 3.9
# 3.8
# 3.8
# 4.0
# 4.0
# 3.8
# 3.7
# 3.7
# 3.9
# 3.9
# 3.7
# 3.9
# 4.0
# 4.1
# 4.1
# 4.0
# 4.0
# 4.1

# %%
company= soup.find_all('div', class_='companyCardWrapper')

# %%
len(company)
# Out:
# 20

# %%
company[0].text.strip()
# Out:
# 'Vodafone Idea\n\t\t\t\t\t\t\t\t\t   Follow   4.2 \n\t\t\t\t\t\t\t\t\tTelecom | 5k-10k Employees | Public | 6 years old | Mumbai +649 more\n\t\t\t\t\t\t\t\t   Highly Rated For Company Culture, Work Life Balance, Salary & Benefits   15.6k Reviews57.3k Salaries468 Interviews11 Jobs2.1k Benefits11 Photos'

# %%
New=[]
for i in company:
    New.append(i.find('h2').text.strip())

# %%
rating=[]
for i in soup.find_all('span', class_='companyCardWrapper__companyRatingValue'):
    rating.append(i.text.strip())

# %%
reviews=[]
for i in soup.find_all('span', class_='companyCardWrapper__ActionCount'):
    print(i.text)
    reviews.append(i.text)
# Out:
# 76.1k
# 8.6L
# 7.3k
# 928
# 11.6k
# 77
# 48.1k
# 5.9L
# 5.1k
# 31.9k
# 7.2k
# 37
# 43.4k
# 5.7L
# 4.2k
# 448
# 5.9k
# 61
# 40.9k
# 4.3L
# 4.1k
# 209
# 5.1k
# 79
# 35.4k
# 4.2L
# 3.4k
# 541
# 4.1k
# 37
# 35k
# 1.3L
# 1.7k
# 175
# 3.3k
# 7
# 34.6k
# 1.4L
# 2k
# 50
# 3.8k
# 46
# 33.1k
# 4.6L
# 5.5k
# 794
# 5.2k
# 88
# 29.7k
# 3L
# 2.8k
# 212
# 4.1k
# 33
# 28.6k
# 2.6L
# 2.7k
# 826
# 3.6k
# 44
# 27k
# 1.9L
# 2.2k
# 553
# 3.7k
# 35
# 22.7k
# 97.5k
# 1.2k
# 212
# 2.2k
# 52
# 23.2k
# 84.9k
# 1.4k
# 306
# 2k
# 25
# 22.5k
# 1.1L
# 1.2k
# 75
# 3.3k
# 41
# 21.2k
# 66.6k
# 1.3k
# 163
# 2.6k
# 43
# 21.4k
# 1.2L
# 3.8k
# 133
# 4.3k
# 69
# 20.3k
# 2.2L
# 1.7k
# 2.3k
# 2.8k
# 18
# 19.5k
# 60.6k
# 1.2k
# 145
# 2k
# 88
# 18.6k
# 49.5k
# 640
# 157
# 1.5k
# 28
# 17.1k
# 78.2k
# 1.1k
# 131
# 2.9k
# 37

# %%
Details =[]
for i in soup.find_all('span', class_='companyCardWrapper__interLinking'):
  
    Details.append(i.text.strip())

# %%
#Salaries =[]
#for i in soup.find_all('span', class_="nav-item__count"):
    #print(i.text.strip())
    #Salaries.append(i.text.strip())

# %%
#New
#rating
reviews
#Details
#Salaries
# Out:
# ['76.1k',
#  '8.6L',
#  '7.3k',
#  '928',
#  '11.6k',
#  '77',
#  '48.1k',
#  '5.9L',
#  '5.1k',
#  '31.9k',
#  '7.2k',
#  '37',
#  '43.4k',
#  '5.7L',
#  '4.2k',
#  '448',
#  '5.9k',
#  '61',
#  '40.9k',
#  '4.3L',
#  '4.1k',
#  '209',
#  '5.1k',
#  '79',
#  '35.4k',
#  '4.2L',
#  '3.4k',
#  '541',
#  '4.1k',
#  '37',
#  '35k',
#  '1.3L',
#  '1.7k',
#  '175',
#  '3.3k',
#  '7',
#  '34.6k',
#  '1.4L',
#  '2k',
#  '50',
#  '3.8k',
#  '46',
#  '33.1k',
#  '4.6L',
#  '5.5k',
#  '794',
#  '5.2k',
#  '88',
#  '29.7k',
#  '3L',
#  '2.8k',
#  '212',
#  '4.1k',
#  '33',
#  '28.6k',
#  '2.6L',
#  '2.7k',
#  '826',
#  '3.6k',
#  '44',
#  '27k',
#  '1.9L',
#  '2.2k',
#  '553',
#  '3.7k',
#  '35',
#  '22.7k',
#  '97.5k',
#  '1.2k',
#  '212',
#  '2.2k',
#  '52',
#  '23.2k',
#  '84.9k',
#  '1.4k',
#  '306',
#  '2k',
#  '25',
#  '22.5k',
#  '1.1L',
#  '1.2k',
#  '75',
#  '3.3k',
#  '41',
#  '21.2k',
#  '66.6k',
#  '1.3k',
#  '163',
#  '2.6k',
#  '43',
#  '21.4k',
#  '1.2L',
#  '3.8k',
#  '133',
# ...

# %%
#d={"Name":New, "Rating":rating, "Reviews":reviews, "Details":Details}
#d={"Name":New, "Rating":rating, "Reviews":reviews, "Details":Details}
#df=pd.DataFrame.from_dict(d, orient='index')
#print(df.transpose())
print(df.shape)
# Out:
# (4, 20)

# %%
company[0].find_all('span',class_='companyCardWrapper__interLinking')[0].text.strip()
# Out:
# 'IT Services & Consulting | 1 Lakh+ Employees | Public | 56 years old | Mumbai +349 more'

# %%
import pandas as pd
Final=pd.DataFrame()
#print(Final_data)
for j in range(1,330):
    url='https://www.ambitionbox.com/list-of-companies?page={}'.format(j)
    headers= {'User-Agent':'Mozilla/5.0 (Window NT 10.0; win64; x64) Applewebkit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
    Web_Page = requests.get(url, headers= headers).text
    soup= BeautifulSoup(Web_Page, 'html.parser')
    company= soup.find_all('div', class_='companyCardWrapper')
    New=[]
    rating=[]
    reviews=[]
    Details=[]
    for i in company:
        New.append(i.find('h2').text.strip())
        rating.append(i.find('span', class_='companyCardWrapper__companyRatingValue').text.strip())
        reviews.append(i.find('span', class_='companyCardWrapper__ActionCount').text.strip())
        Details.append(i.find('span', class_='companyCardWrapper__interLinking').text.strip())
    
    d={"Name":New, "Rating":rating, "Reviews":reviews, "Details":Details}
    df=pd.DataFrame.from_dict(d, orient='index')
    df1=df.transpose()
    #print(df.transpose())
    #print(df.shape)
    #print(df1)
    Final=pd.concat((df1, Final),ignore_index=True)

# %%
#Final.head()
#Final.sample(20)
Final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3980 entries, 0 to 3979
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3980 non-null   object
#  1   Rating   3980 non-null   object
#  2   Reviews  3980 non-null   object
#  3   Details  3980 non-null   object
# dtypes: object(4)
# memory usage: 124.5+ KB

# %%
Final.shape
Final.to_csv("E:\Ambition_box_data.csv")

# %%
New=[]
rating=[]
reviews=[]
Details=[]
for i in company:
    New.append(i.find('h2').text.strip())
    rating.append(i.find('span', class_='companyCardWrapper__companyRatingValue').text.strip())
    reviews.append(i.find('span', class_='companyCardWrapper__ActionCount').text.strip())
    Details.append(i.find('span', class_='companyCardWrapper__interLinking').text.strip())

d={"Name":New, "Rating":rating, "Reviews":reviews, "Details":Details}
df=pd.DataFrame.from_dict(d, orient='index')
print(df.transpose())
print(df.shape)
# Out:
#                           Name Rating Reviews  \
# 0                Vodafone Idea    4.2   15.6k
# 1                       BYJU'S    3.1   15.2k
# 2          Kotak Mahindra Bank    3.9   14.7k
# 3                     Deloitte    3.9   14.5k
# 4          Reliance Industries    4.1   14.1k
# 5                   iEnergizer    4.7   15.3k
# 6                Bharti Airtel    4.1   12.6k
# 7                  Tata Motors    4.2   10.8k
# 8                          WNS    3.5     10k
# 9                     Flipkart    4.1    9.6k
# 10               IndusInd Bank    3.7    9.5k
# 11               Ernst & Young    3.6    9.3k
# 12       AU Small Finance Bank    4.4    8.9k
# 13         Mahindra & Mahindra    4.2    8.9k
# 14                 Infosys BPM    3.8    8.6k
# 15              DXC Technology    3.8    8.6k
# 16             IDFC FIRST Bank    4.0    8.6k
# 17  Conneqt Business Solutions    3.8    8.2k
# 18                 LTIMindtree    3.6    8.2k
# ...

# %%
headers= {'User-Agent':'Mozilla/5.0 (Window NT 10.0; win64; x64) Applewebkit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
Web_Page = requests.get("https://www.linkedin.com/jobs/recruiter-jobs-new-delhi/?currentJobId=3848653138&originalSubdomain=in", headers= headers).text
#requests.get("https://www.youtube.com/results?search_query=Data+Science", headers= headers).text

# %%
soup= BeautifulSoup(Web_Page, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="d_jobs_guest_search" name="pageKey"/>
#   <!-- -->
#   <meta content="urlType=jserp_non_canonical;emptyResult=false" name="linkedin:pageTag"/>
#   <meta content="en_US" name="locale"/>
#   <meta data-app-version="2.0.1740" data-browser-id="6e2c2676-1a35-42b9-8ed1-f82a6c3be358" data-call-tree-id="AAYXEEUHb3wgrOGByBmg9A==" data-disable-jsbeacon-pagekey-suffix="false" data-enable-page-view-heartbeat-tracking="" data-member-id="0" data-multiproduct-name="jobs-guest-frontend" data-page-instance="urn:li:page:d_jobs_guest_search;S/WLim9fSPSLiP6pe2FSww==" data-service-name="jobs-guest-frontend" id="config"/>
#   <link href="https://in.linkedin.com/jobs/recruiter-jobs-new-delhi" rel="canonical"/>
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <link href="https://static.licdn.com/aero-v1/sc/h/al2o9zrvru7aqj8e1x2rzsrca" rel="icon"/>
#   <script>
# ...

# %%
print(soup.find_all('h1')[0].text)
# Out:
# 76 Recruiter Jobs in New Delhi

# %%
print(len(soup.find_all('h2')))
# Out:
# 1

# %%
for i in soup.find_all('h2'):
    print(i.text.strip())
# Out:
# You’re signed out

# %%
for i in soup.find_all('span'):
    print(i.text.strip())
# Out:
# LinkedIn
# Expand search
#
#
#
#
#
# Recruiter
# 76
# Recruiter Jobs in New Delhi
# Recruitment Manager
# West Delhi, Delhi, India
# Actively Hiring
# Consultant (Talent Acquisition)/Recruiter
# Defence Colony, Delhi, India
# HR Executive/Recruiter-Work from office/Delhi
# Delhi, India
# Actively Hiring
# Recruiter
# Defence Colony, Delhi, India
# Recruitment Manager
# New Delhi, Delhi, India
# Actively Hiring
# Technical Recruiter
# West Delhi, Delhi, India
# Actively Hiring
# HR Recruiter
# Delhi, India
# Actively Hiring
# HR Recruiter
# Saket, Delhi, India
# Actively Hiring
# APAC Talent Acquisition Senior Specialist
# New Delhi, Delhi, India
# Actively Hiring
# IT Recruiter
# Delhi Cantonment, Delhi, India
# Actively Hiring
# HR Recruiter
# New Delhi, Delhi, India
# Actively Hiring
# HR Associate
# New Delhi, Delhi, India
# HR Recruiter
# Delhi Cantonment, Delhi, India
# Actively Hiring
# Senior Talent Acquisition Specialist
# Rohini, Delhi, India
# Be an early applicant
# ...

# %%
print(soup.find_all('h1'))
# Out:
# [<h1 class="results-context-header__context">
# <span class="results-context-header__job-count">76</span> <span class="results-context-header__query-search">Recruiter Jobs in New Delhi</span>
# </h1>]

# %%
print(soup.find_all('button'))
# Out:
# [<button class="search-bar__placeholder papabear:hidden text-input w-full mt-1.5 !pl-[14px] border-1 border-solid border-color-border-faint rounded-[2px] h-[40px] max-h-[40px] flex items-center overflow-hidden cursor-text" data-tracking-control-name="public_jobs_search-switcher-opener">
# <icon class="text-color-icon w-3 h-3 mr-1" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/397vrsk6op88l4981ji1xe1qt"></icon>
# <div class="search-bar__full-placeholder font-sans text-md text-color-text max-w-[calc(100%-40px)] text-left whitespace-nowrap overflow-hidden text-ellipsis">
# <!-- -->              Recruiter in New Delhi
# <!-- --><!-- --> </div>
# <span class="sr-only">Expand search</span>
# ...
